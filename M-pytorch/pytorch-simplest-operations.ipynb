# %%
import torch

# %% [markdown]
# ## 1. Creating tensors

# %%
# Scalar 
scalar = torch.tensor(5)

# vector
vector = torch.tensor([1, 2, 3])

# Matrix
matrix = torch.tensor([[1, 2], [3, 4]])

print(f"scalar: {scalar}")
print(f"vector: {vector}")
print(f"matrix: {matrix}")
# Out:
# scalar: 5
# vector: tensor([1, 2, 3])
# matrix: tensor([[1, 2],
#         [3, 4]])

# %% [markdown]
# ## 2. Basic Mathematical Operations

# %%
x = torch.tensor([2, 3, 4])
y = torch.tensor([5, 6, 7])

add = x + y
print(f"Addition: {add}")

sub = y - x
print(f"Substraction : {sub}")

mul = x * y
print(f"Multiply: {mul}")

div = y / x
print(f"Divide: {div}")
# Out:
# Addition: tensor([ 7,  9, 11])
# Substraction : tensor([3, 3, 3])
# Multiply: tensor([10, 18, 28])
# Divide: tensor([2.5000, 2.0000, 1.7500])

# %% [markdown]
# ## 3. Reshaping and casting

# %%
tensor = torch.tensor([[1, 2, 3], [4, 5, 6]])

reshaped_tensor = tensor.view(3, 2)

float_tensor = tensor.float()

print(f"Reshaped: {reshaped_tensor}")

print(f"Casted: {float_tensor}")
# Out:
# Reshaped: tensor([[1, 2],
#         [3, 4],
#         [5, 6]])
# Casted: tensor([[1., 2., 3.],
#         [4., 5., 6.]])

# %% [markdown]
# ## 4. Indexing and Slicing

# %%
tensor = torch.tensor([10, 20, 30, 40, 50])

print(tensor[0])

print(tensor[1:4])
# Out:
# tensor(10)
# tensor([20, 30, 40])
