# %%
class BankAccount:
    def __init__(self, owner: str, balance: float = 0.0):
        self.owner = owner
        self._balance = balance
    
    def deposit(self, amount: float):
        if amount <= 0:
            print(f"Deposit {amount:.2f} invalid, must be postive amount.")
        else:
            self._balance += amount
            print(f"Deposited ${amount:.2f}")
    
    def withdraw(self, amount: float):
        if 0 < amount <= self._balance:
            self._balance -= amount
            print(f"Withdrew $ {amount:.2f}")
        else:
            print("Insufficient funds or invalid amount")

    def get_balance(self) -> float:
        return f"${self._balance}"
    
    def __str__(self):
        return f"Account(owner = {self.owner}, balance=${self._balance:.2f})"

# %%
acc = BankAccount("Carlos Ramirez", 100)
print(acc)
acc.deposit(250)
print(acc.get_balance())

acc.deposit(0)
print(acc.get_balance())

acc.deposit(-220)
print(acc.get_balance())

acc.withdraw(300)
print(acc.get_balance())

acc.withdraw(300)
print(acc.get_balance())
# Out:
# Account(owner = Carlos Ramirez, balance=$100.00)
# Deposited $250.00
# $350
# Deposit 0.00 invalid, must be postive amount.
# $350
# Deposit -220.00 invalid, must be postive amount.
# $350
# Withdrew $ 300.00
# $50
# Insufficient funds or invalid amount
# $50

# %%
class
