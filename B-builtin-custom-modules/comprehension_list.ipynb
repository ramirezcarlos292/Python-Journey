# %% [markdown]
# # List Comprehension
# A way to create a new list with less syntax, mimic lambda functions<br>
#
# syntax<br>
# - list = [expression for item in iterable]
# - list = [expression for item in iterable if conditional]
# - list = [expression (if/else) for item in iterable]

# %%
squares = [x * x for x in range(1, 11)]
squares
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
students = [100, 90, 80, 70, 60, 50, 40, 30, 0]
passed_students = list(filter(lambda x: x >=60, students))
passed_students
# Out:
# [100, 90, 80, 70, 60]

# %%
passed_students = [i for i in students if i >= 60]
passed_students
# Out:
# [100, 90, 80, 70, 60]

# %%
passed_students = [i if i >= 60 else "Failed" for i in students]
passed_students
# Out:
# [100, 90, 80, 70, 60, 'Failed', 'Failed', 'Failed', 'Failed']

# %% [markdown]
# # Copilot challenges
#
# Great idea! I found some Python list comprehension challenges that match your request. Here are 12 exercises categorized by difficulty:
#
# ### **Easy Challenges**
# 1. **Reverse a list** – Given `[100, 200, 300, 400, 500]`, return `[500, 400, 300, 200, 100]`.
# 2. **Concatenate two lists index-wise** – Given `["M", "na", "i", "Ke"]` and `["y", "me", "s", "lly"]`, return `["My", "name", "is", "Kelly"]`.
# 3. **Square each element** – Given `[1, 2, 3, 4, 5, 6, 7]`, return `[1, 4, 9, 16, 25, 36, 49]`.
# 4. **Concatenate two lists in all possible orders** – Given `["Hello ", "take "]` and `["Dear", "Sir"]`, return `["Hello Dear", "Hello Sir", "take Dear", "take Sir"]`.

# %%
# 1. reverse list
asc_list = [100, 200, 300, 400, 500]
desc_list = [asc_list[x] for x in range(len(asc_list)-1, -1, -1)]
desc_list
# Out:
# [500, 400, 300, 200, 100]

# %%
# 2. Concatenate two lists index-wise
l1 = ["M", "na", "i", "Ke"]
l2 = ["y", "me", "s", "lly"]
print([l1[x]+l2[x] for x in range(len(l1))])
# Out:
# ['My', 'name', 'is', 'Kelly']

# %%
# 3. square elements of list
squared = [x * x for x in range(1, 11)]
squared
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
# 4. Concatenate two lists in all possible orders
l1 = ["Hello", "take"]
l2 = ["Dear", "Sir"]
res = []
for i in range(len(l1)):
    for j in range(len(l2)):
        temp = l1[i] + " " + l2[j]
        res.append(temp)
print(res)


l1 = ["Hello", "take"]
l2 = ["Dear", "Sir"]

p3 = [l1[i]+ " " + l2[j] for j in range(len(l2)) for i in range(len(l1))]
print(p3)
# Out:
# ['Hello Dear', 'Hello Sir', 'take Dear', 'take Sir']
# ['Hello Dear', 'take Dear', 'Hello Sir', 'take Sir']

# %% [markdown]
# ### **Medium Challenges**
# 5. **Filter even numbers** – Given `[1, 2, 3, 4, 5, 6, 7, 8]`, return `[2, 4, 6, 8]`.
# 6. **Extract words with more than 3 letters** – Given `["hi", "hello", "bye", "goodbye"]`, return `["hello", "goodbye"]`.
# 7. **Flatten a nested list** – Given `[[1, 2], [3, 4], [5, 6]]`, return `[1, 2, 3, 4, 5, 6]`.
# 8. **Find common elements in two lists** – Given `[1, 2, 3, 4]` and `[3, 4, 5, 6]`, return `[3, 4]`.

# %%
# 5. Filter even numbers
res = [x for x in range(1, 10) if x % 2 == 0]
print(res)
# Out:
# [2, 4, 6, 8]

# %%
# 6. Extract words with more than 3 letters
lst = ["hi", "hello", "bye", "goodbye"]
res = [x for x in lst if len(x) > 3]
res
# Out:
# ['hello', 'goodbye']

# %%
# 7. Flatten a nested list
nested_lst = [[1, 2], [3, 4], [5, 6]]
flatten = []
for i in nested_lst:
    for j in range(len(i)):
        flatten.append(i[j])
flatten
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# 8. Find common elements in two lists
l1 = [1, 2, 3, 4]
l2 = [3, 4, 5, 6]

s1 = set(l1)
s2 = set(l2)
print(list(s1&s2))

res = []
res
# Out:
# [3, 4]
# [True, True, False, False]

# %% [markdown]
# ### **Hard Challenges**
# 9. **Generate a list of prime numbers** – Given `range(1, 50)`, return a list of primes.
# 10. **Transpose a matrix using list comprehension** – Given `[[1, 2, 3], [4, 5, 6], [7, 8, 9]]`, return `[[1, 4, 7], [2, 5, 8], [3, 6, 9]]`.
# 11. **Remove duplicates while preserving order** – Given `[1, 2, 2, 3, 4, 4, 5]`, return `[1, 2, 3, 4, 5]`.
# 12. **Sort a list of tuples by the second element** – Given `[(1, 3), (2, 2), (3, 1)]`, return `[(3, 1), (2, 2), (1, 3)]`.

# %%
def is_prime(number):
    if number <= 1:
        return
    for i in range(2, int(number ** 0.5) + 1):
        if number % i != 0:
            return number

for i in range(0, 15):
    print(f"{is_prime(i)}")
# Out:
# None
# None
# None
# None
# None
# 5
# None
# 7
# None
# 9
# 10
# 11
# None
# 13
# 14
