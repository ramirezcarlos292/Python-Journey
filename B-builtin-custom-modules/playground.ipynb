# %%
cities_in_F = {'New York': 32, 'Boston': 75, 'Los Angeles': 100, 'Chicago': 50}

cities_in_C = {key: round(((value-32)*(5/9))) for (key, value) in cities_in_F.items()}
cities_in_C
# Out:
# {'New York': 0, 'Boston': 24, 'Los Angeles': 38, 'Chicago': 10}

# %%
thermal_sensation = {key: ("WARM" if value >= 40 else "COLD") for (key, value) in cities_in_F.items()}

thermal_sensation
# Out:
# {'New York': 'COLD',
#  'Boston': 'WARM',
#  'Los Angeles': 'WARM',
#  'Chicago': 'WARM'}

# %%
def check_temp(value):
    if value >= 70:
        return 'HOT'
    elif 69 >= value >= 40:
        return 'WARM'
    else:
        return 'COLD'
    
thermal_sensation = {key: (check_temp(value)) for (key, value) in cities_in_F.items()}
thermal_sensation
# Out:
# {'New York': 'COLD', 'Boston': 'HOT', 'Los Angeles': 'HOT', 'Chicago': 'WARM'}

# %%
squares = [x * x for x in range(1, 11)]
squares
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
roots = [round(x ** (1/2), 3) for x in range(1, 11)]
roots
# Out:
# [1.0, 1.414, 1.732, 2.0, 2.236, 2.449, 2.646, 2.828, 3.0, 3.162]

# %%
import random
students = [random.randint(0, 100) for x in range(1, 20)]

passed_students = list(filter(lambda x: x >= 60, students))
passed_students
# Out:
# [71, 67, 79, 72, 61, 97, 93, 70]

# %%
passed_students = [i if i >= 60 else "Failed" for i in students]
passed_students
# Out:
# [71,
#  67,
#  'Failed',
#  79,
#  'Failed',
#  'Failed',
#  'Failed',
#  'Failed',
#  'Failed',
#  'Failed',
#  72,
#  'Failed',
#  61,
#  97,
#  93,
#  70,
#  'Failed',
#  'Failed',
#  'Failed']

# %%
def decorator(func):
    def wrapper(*args, **kwargs):
        print("decorated")
        func(*args, **kwargs)
        print('bye')
    return wrapper

# @decorator
def my_func():
    print("Hello World!")
    
my_func()
# Out:
# Hello World!

# %%
def log_function_call(func):
    def wrapper(*args, **kwargs):
        print(f"Calling function '{func.__name__}' with {args}, kwargs {kwargs}")
        result = func(*args, **kwargs)
        print(f"{func.__name__} return {result}")
        return result
    return wrapper

@log_function_call
def add(a, b, c= "Silverster"):
    return a + b

add(5, 2)
# Out:
# Calling function 'add' with (5, 2), kwargs {}
# add return 7
# 7

# %%
import time

def time_it(func):
    def wrapper(*args, **kwargs):
        start_timer = time.time()
        result = func(*args, **kwargs)
        end_timer = time.time()
        print(f"{func.__name__} took {end_timer - start_timer} seconds to finish")
        return result
    return wrapper

@time_it
def slow_function():
    time.sleep(2)
    
slow_function()
# Out:
# slow_function took 2.0009686946868896 seconds to finish

# %%
def cache(func):
    cache_dict = {}
    def wrapper(*args):
        if args in cache_dict:
            return cache_dict[args]
        result = func(*args)
        cache_dict[args] = result
        return result
    return wrapper

# @cache
def fibonacci(n):
    if n <= 1:
        return n
    else:
        return fibonacci(n-1) + fibonacci(n-2)
fibonacci(50)
# Out:
# 12586269025

# %%
s = "GFG"
it = iter(s)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# G
# F
# G
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[12], line 6
#       4 print(next(it))
#       5 print(next(it))
# ----> 6 print(next(it))
#
# StopIteration:

# %%
class EvenNumbers:
    def __iter__(self):
        self.n = 2
        return self
    
    def __next__(self):
        x = self.n
        self.n += 2
        return x
    
even = EvenNumbers()
it = iter(even)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# 2
# 4
# 6
# 8
# 10
# 12

# %%
run_times = 8
for run in range(run_times):
    print(next(it))
# Out:
# 14
# 16
# 18
# 20
# 22
# 24
# 26
# 28

# %%
li = [100, 200, 300]
it = iter(li)

while True:
    try:
        print(next(it))
    except StopIteration:
        print("End of Iteration")
        break
# Out:
# 100
# 200
# 300
# End of Iteration

# %%
x = lambda a: a + 10
print(x(5))

x = lambda a, b: a * b
print(x(5, 6))

x = lambda a, b: a / b
print(x(5, 6))
# Out:
# 15
# 30
# 0.8333333333333334

# %%
# concatenate
full_name = lambda first_name, last_name: first_name + ' ' + last_name
print(full_name("Silvester", "Stallone"))
# Out:
# Silvester Stallone

# %%
age_check = lambda age: True if age >= 18 else False
print(age_check(21))
# Out:
# True

# %%
data = [(1, 'apple'), (6, 'cherry'), (5, 'banana')]
sorted_data = sorted(data, key=lambda x: x[1])
sorted_data
# Out:
# [(1, 'apple'), (5, 'banana'), (6, 'cherry')]

# %%
import random

numbers = [random.randint(1, 12) for x in range(10)]
even = list(filter(lambda x: x % 2 == 0, numbers))
even
# Out:
# [6, 10, 10, 8, 10]

# %%
squared = list(map(lambda x: x**2, numbers))
squared
# Out:
# [36, 100, 100, 121, 64, 1, 49, 49, 100, 81]

# %%
def ininite_numbers():
    num = 0
    while True:
        yield num
        num += 1
        
gen = ininite_numbers()
for _ in range(1001, 1):
    print(next(gen))
