# %% [markdown]
# # Regex
# https://regextutorial.org/

# %%
import re

# %%
# 1. Marching digits
print(re.findall(r'\d', 'Price: 100 dollars'))
# Out:
# ['1', '0', '0']

# %%
#2. Matching Word chraracters
print(re.findall(r'\w', 'Hello World!'))
# Out:
# ['H', 'e', 'l', 'l', 'o', 'W', 'o', 'r', 'l', 'd']

# %%
# 3. Matching Whitespaces
print(re.findall(r'\s', 'Hello World '))
# Out:
# [' ', ' ']

# %%
# 4. Matching the start of a string
print(re.search(r'World', 'Hello World'))
# Out:
# <re.Match object; span=(6, 11), match='World'>

# %%
# 5. Matching any character
print(re.findall(r'H.llo', 'Hello, H3llo, H*llo'))
# Out:
# ['Hello', 'H3llo', 'H*llo']

# %%
# 6. Matching zero or more occurrences
print(re.findall(r'a*b', 'aaab abb acb'))
# Out:
# ['aaab', 'ab', 'b', 'b']

# %%
# 7. Matching one or more ocurrences
print(re.findall(r'a+b', 'aaab abb acb'))
# Out:
# ['aaab', 'ab']

# %%
# 8. Matching optional characters
print(re.findall(r'colou?r', 'color colour'))
# Out:
# ['color', 'colour']

# %%
# Character classes
print(re.findall(r'[aeiou]', 'Hello World'))
# Out:
# ['e', 'o', 'o']
